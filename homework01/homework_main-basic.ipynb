# %% [markdown]
# # Homework: Basic Artificial Neural Networks

# %% [markdown]
# The goal of this homework is simple, yet an actual implementation may take some time :). We are going to write an Artificial Neural Network (almost) from scratch. The software design was heavily inspired by [PyTorch](http://pytorch.org) which is the main framework of our course

# %% [markdown]
# This homework requires sending **multiple** files, please do not forget to include all the files when sending to TA. The list of files:
# - This notebook
# - homework_modules.ipynb with all blocks implemented (except maybe `Conv2d` and `MaxPool2d` layers implementation which are part of 'advanced' version of this homework)
# - homework_differentiation.ipynb

# %%
# %matplotlib inline
from time import time, sleep
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython import display

# %% [markdown]
# # Framework

# %% [markdown]
# Implement everything in `Modules.ipynb`. Read all the comments thoughtfully to ease the pain. Please try not to change the prototypes.
#
# Do not forget, that each module should return **AND** store `output` and `gradInput`.
#
# The typical assumption is that `module.backward` is always executed after `module.forward`,
# so `output` is stored, this would be useful for `SoftMax`.

# %% [markdown]
# ### Tech note
# Prefer using `np.multiply`, `np.add`, `np.divide`, `np.subtract` instead of `*`,`+`,`/`,`-` for better memory handling.
#
# Example: suppose you allocated a variable
#
# ```
# a = np.zeros(...)
# ```
# So, instead of
# ```
# a = b + c  # will be reallocated, GC needed to free
# ```
# You can use:
# ```
# np.add(b,c,out = a) # puts result in `a`
# ```

# %%
# (re-)load layers
# %run homework_modules.ipynb

# %% [markdown]
# # Toy example

# %% [markdown]
# Use this example to debug your code, start with logistic regression and then test other layers. You do not need to change anything here. This code is provided for you to test the layers. Also it is easy to use this code in MNIST task.

# %%
# Generate some data
N = 500

X1 = np.random.randn(N,2) + np.array([2,2])
X2 = np.random.randn(N,2) + np.array([-2,-2])

Y = np.concatenate([np.ones(N),np.zeros(N)])[:,None]
Y = np.hstack([Y, 1-Y])

X = np.vstack([X1,X2])
plt.scatter(X[:,0],X[:,1], c = Y[:,0], edgecolors= 'none')

# %% [markdown]
# Define a **logistic regression** for debugging.

# %%
net = Sequential()
net.add(Linear(2, 2))
net.add(LogSoftMax())

criterion = ClassNLLCriterion()

print(net)

# Test something like that then 

# net = Sequential()
# net.add(Linear(2, 4))
# net.add(ReLU())
# net.add(Linear(4, 2))
# net.add(LogSoftMax())
# Out:
# Linear 2 -> 2
# LogSoftMax

# %% [markdown]
# Start with batch_size = 1000 to make sure every step lowers the loss, then try stochastic version.

# %%
# Iptimizer params
optimizer_config = {'learning_rate' : 1e-1, 'momentum': 0.9}
optimizer_state = {}

# Looping params
n_epoch = 20
batch_size = 128

# %%
# batch generator
def get_batches(dataset, batch_size):
    X, Y = dataset
    n_samples = X.shape[0]
        
    # Shuffle at the start of epoch
    indices = np.arange(n_samples)
    np.random.shuffle(indices)
    
    for start in range(0, n_samples, batch_size):
        end = min(start + batch_size, n_samples)
        
        batch_idx = indices[start:end]
    
        yield X[batch_idx], Y[batch_idx]

# %% [markdown]
# ### Train

# %% [markdown]
# Basic training loop. Examine it.

# %%
loss_history = []

for i in range(n_epoch):
    for x_batch, y_batch in get_batches((X, Y), batch_size):
        
        net.zeroGradParameters()
        
        # Forward
        predictions = net.forward(x_batch)
        loss = criterion.forward(predictions, y_batch)
    
        # Backward
        dp = criterion.backward(predictions, y_batch)
        net.backward(x_batch, dp)
        
        # Update weights
        sgd_momentum(net.getParameters(), 
                     net.getGradParameters(), 
                     optimizer_config,
                     optimizer_state)      
        
        loss_history.append(loss)

    # Visualize
    display.clear_output(wait=True)
    plt.figure(figsize=(8, 6))
        
    plt.title("Training loss")
    plt.xlabel("#iteration")
    plt.ylabel("loss")
    plt.plot(loss_history, 'b')
    plt.show()
    
    print('Current loss: %f' % loss)
# Out:
# Current loss: 0.011215

# %% [markdown]
# ### Show accuracy
#
# Here I'll plot the correctly/wrongly classified points and show the accuracy score.

# %%
predictions = np.exp(net.forward(X)).argmax(axis=1)
truth = Y.argmax(axis=1)
correct = predictions == truth

plt.scatter(X[:,0],X[:,1], c = correct, edgecolors= 'none')
print(f'Accuracy: {correct.mean():.4f}')
# Out:
# Accuracy: 0.9970

# %% [markdown]
# # Digit classification

# %% [markdown]
# We are using old good [MNIST](http://yann.lecun.com/exdb/mnist/) as our dataset.

# %%
import mnist
X_train, y_train, X_val, y_val, X_test, y_test = mnist.load_dataset()

# %% [markdown]
# One-hot encode the labels first.

# %%
from sklearn.preprocessing import OneHotEncoder

y_train = np.expand_dims(y_train, axis=1)
y_val = np.expand_dims(y_val, axis=1)
y_test = np.expand_dims(y_test, axis=1)

enc = OneHotEncoder().fit(y_train)

y_train = enc.transform(y_train).toarray()
y_val = enc.transform(y_val).toarray()
y_test = enc.transform(y_test).toarray()

print(X_train.shape, y_train.shape)
# Out:
# (50000, 28, 28) (50000, 10)

# %% [markdown]
# - **Compare** `ReLU`, `ELU`, `LeakyReLU`, `SoftPlus` activation functions.
# You would better pick the best optimizer params for each of them, but it is overkill for now. Use an architecture of your choice for the comparison.
# - **Try** inserting `BatchNormalization` (folowed by `ChannelwiseScaling`) between `Linear` module and activation functions.
# - Plot the losses both from activation functions comparison and `BatchNormalization` comparison on one plot. Please find a scale (log?) when the lines are distinguishable, do not forget about naming the axes, the plot should be goodlooking.
# - Plot the losses for two networks: one trained by momentum_sgd, another one trained by Adam. Which one performs better?
# - Hint: good logloss for MNIST should be around 0.5.

# %%
criterion = ClassNLLCriterion()

def construct_net(activation):
    net = Sequential()
    net.add(Flatten())
    net.add(Linear(28*28, 10))
    net.add(activation())   
    net.add(Linear(10, 10))
    net.add(LogSoftMax())    

    return net

def train(model, train_x, train_y, val_x, val_y, batch_size, n_epoch,  
          optimizer_config, optimizer = sgd_momentum, visualize=False):
    loss_history = []
    validate_history = []
    optimizer_state = {}
    
    for i in range(n_epoch):
        # Train the model
        model.train()
        for x_batch, y_batch in get_batches((train_x, train_y), batch_size):
            
            model.zeroGradParameters()
            
            # Forward
            predictions = model.forward(x_batch)
            loss = criterion.forward(predictions, y_batch)
        
            # Backward
            dp = criterion.backward(predictions, y_batch)
            model.backward(x_batch, dp)
            
            # Update weights
            optimizer(model.getParameters(), 
                        model.getGradParameters(), 
                        optimizer_config,
                        optimizer_state)      
            
            loss_history.append(loss)

        # Visualize
        display.clear_output(wait=True)

        if visualize:
            plt.figure(figsize=(8, 6))
                
            plt.title("Training loss")
            plt.xlabel("#iteration")
            plt.ylabel("loss")
            plt.plot(loss_history, 'b')
            plt.show()
         
        # Validation
        model.evaluate()
        predictions = np.exp(model.forward(val_x)).argmax(axis=1)
        truth = val_y.argmax(axis=1)
        acc = (predictions == truth).mean()
        validate_history.append(acc)
        
        print(f'Epoch {i+1}/{n_epoch}: Training loss {loss:.4f}. Validation accuracy: {acc:.4f}')
                
    return loss_history, validate_history

# %% [markdown]
# ### ReLU

# %%
# Define the net
net = construct_net(ReLU)

BATCH_SIZE = 128
N_EPOCHS = 25
optimizer_config = {'learning_rate' : 1e-2, 'momentum': 0.9}

start = time()
loss_relu, acc_relu = train(net, X_train, y_train, X_val, y_val, BATCH_SIZE, N_EPOCHS, optimizer_config)
end = time()
print(f'Time per epoch: {(end-start)/N_EPOCHS:.2f} seconds')
# Out:
# Epoch 25/25: Training loss 0.2779. Validation accuracy: 0.9433
# Time per epoch: 0.87 seconds

# %% [markdown]
# ## ELU

# %%
# Define the net
net = construct_net(ELU)

start = time()
loss_elu, acc_elu = train(net, X_train, y_train, X_val, y_val, BATCH_SIZE, N_EPOCHS, optimizer_config)
end = time()
print(f'Time per epoch: {(end-start)/N_EPOCHS:.2f} seconds')
# Out:
# Epoch 25/25: Training loss 0.1895. Validation accuracy: 0.9402
# Time per epoch: 1.11 seconds

# %% [markdown]
# ### LeakyReLU

# %%
# Define the net
net = construct_net(LeakyReLU)

start = time()
loss_leaky_relu, acc_leaky_relu = train(net, X_train, y_train, X_val, y_val, BATCH_SIZE, N_EPOCHS, 
                                        optimizer_config)
end = time()
print(f'Time per epoch: {(end-start)/N_EPOCHS:.2f} seconds')
# Out:
# Epoch 25/25: Training loss 0.0821. Validation accuracy: 0.9434
# Time per epoch: 1.05 seconds

# %% [markdown]
# ### SoftPlus

# %%
# Define the net
net = construct_net(SoftPlus)

start = time()
loss_softplus, acc_softplus = train(net, X_train, y_train, X_val, y_val, BATCH_SIZE, N_EPOCHS, 
                                    optimizer_config)
end = time()
print(f'Time per epoch: {(end-start)/N_EPOCHS:.2f} seconds')
# Out:
# Epoch 25/25: Training loss 0.3398. Validation accuracy: 0.9354
# Time per epoch: 1.05 seconds

# %% [markdown]
# ### BatchNormalization with ReLU

# %%
net = Sequential()
net.add(Flatten())
net.add(Linear(28*28, 10))
net.add(BatchNormalization(alpha=0.9))
net.add(ChannelwiseScaling(10))
net.add(ReLU())
net.add(Linear(10, 10))
net.add(LogSoftMax()) 

start = time()
loss_relu_bn, acc_relu_bn = train(net, X_train, y_train, X_val, y_val, BATCH_SIZE, N_EPOCHS, 
                                  optimizer_config)
end = time()
print(f'Time per epoch: {(end-start)/N_EPOCHS:.2f} seconds')
# Out:
# Epoch 25/25: Training loss 0.1439. Validation accuracy: 0.9302
# Time per epoch: 1.12 seconds

# %% [markdown]
# ### ReLU with Adam

# %%
# Define the net
net = construct_net(ReLU)

optimizer_config = {'learning_rate' : 1e-2, 'beta1':0.9, 'beta2':0.999, 'epsilon': 1e-3}

start = time()
loss_relu_adam, acc_relu_adam = train(net, X_train, y_train, X_val, y_val, BATCH_SIZE, N_EPOCHS, 
                                      optimizer_config, optimizer=adam_optimizer)
end = time()
print(f'Time per epoch: {(end-start)/N_EPOCHS:.2f} seconds')
# Out:
# Epoch 25/25: Training loss 0.2048. Validation accuracy: 0.9281
# Time per epoch: 1.32 seconds

# %% [markdown]
# ### Comparison

# %%
losses = np.vstack([loss_relu, loss_elu, loss_leaky_relu, loss_softplus, loss_relu_bn, loss_relu_adam])
losses = pd.DataFrame(losses.T, columns = ['ReLU', 'ELU', 'Leaky ReLU', 'Softplus', 'ReLU + BN', 
                                           'ReLU + Adam'])

accuracies = np.vstack([acc_relu, acc_elu, acc_leaky_relu, acc_softplus, acc_relu_bn, acc_relu_adam])
accuracies = pd.DataFrame(accuracies.T, columns = losses.columns)
accuracies.index.name = 'Epoch'

losses_smooth = losses.rolling(X_train.shape[0]//BATCH_SIZE).mean().dropna()# + 1
losses_smooth.index = losses_smooth.index/(X_train.shape[0]//BATCH_SIZE)
losses_smooth.index.name = 'Epoch'
losses_smooth.plot(title='Training loss')

# %%
accuracies.plot(title='Validation accuracy')

# %% [markdown]
# Write your personal opinion on the activation functions, think about computation times too. Does `BatchNormalization` help?

# %% [markdown]
# #### Answer
#
# Well, so for the architecture I am using, there is very little difference (just didn't feel like trying out 100 different architectures). Surprisingly, `ReLU` and `LeakyReLU` perform the best, and `BatchNorm` and `Adam` dissapoint (probably would need to tweak the parameters for them a bit). However, we see that `Adam` reaches a very high accuracy already on the first epoch.
#
# Regarding speed - as expected, `ReLU` wins, as it is the simples. Surprisingly `LeakyReLU` is just as fast (slow) as the exponential activations, and the exponential activations are not even that much slower than `ReLU`.

# %% [markdown]
# **Finally**, use all your knowledge to build a super cool model on this dataset. Use **dropout** to prevent overfitting, play with **learning rate decay**. You can use **data augmentation** such as rotations, translations to boost your score. Use your knowledge and imagination to train a model. Don't forget to call `training()` and `evaluate()` methods to set desired behaviour of `BatchNormalization` and `Dropout` layers.

# %% [markdown]
# #### Answer
#
# I did the cool model for the advanced part :)

# %% [markdown]
# Print here your accuracy on test set. It should be around 90%.
